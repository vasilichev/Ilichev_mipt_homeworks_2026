# %% [markdown]
# # Семинар "Исключения"

# %% [markdown]
# # Задача 1 (Читаем файл)

# %%
path = "seminar_files/data.txt"

file_obj = open(path, encoding="ascii")
text = file_obj.read()
print(text[:200])
# Out:
# Hello world!

# %% [markdown]
# # Задача 2 (Ищем квартиру посуточно)

# %% [markdown]
# Допустим, мы хотим сделать систему для посуточной аренды квартир.
#
# У квартиры есть: идентификатор, полный адрес, количество комнат, стоимость аренды за сутки.
#
# Также нам нужно хранить данные об аренде: идентификатор квартиры, день начала аренды, день окончания аренды.
#
# Нужно дать пользователю возможность:
#
# 1. Искать квартиры по заданному периоду
# 2. Бронировать квартиру

# %%
with open("seminar_files/apartments.csv", mode ="r") as file:
    csvFile = csv.reader(file, delimiter=";")
    for lines in csvFile:
        print(lines)
# Out:
# ['1', 'г. Москва, Лубянка, д.41, кв.5', '2', '10000']
# ['2', 'г. Москва, Старая Басманная, д.3, кв.4', '3', '15000']
# ['3', 'г. Москва, ш. Московское, д.23 к.5', '1', '1000']

# %%
with open("seminar_files/apart_rent.csv", mode ="r") as file:
    csvFile = csv.reader(file, delimiter=";")
    for lines in csvFile:
        print(lines)
# Out:
# ['1', '12/04/2026', '14/04/2026']
# ['1', '16/04/2026', '19/04/2026']
# ['2', '13/04/2026', '15/04/2026']

# %%
from datetime import datetime
date_object = datetime.strptime(date_string, "%d/%m/%Y").date()
